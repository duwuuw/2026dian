# %%
import os
os.environ["KMP_DUPLICATE_LIB_OK"] = "TRUE"
os.environ["OMP_NUM_THREADS"] = "1"
os.environ["CUDA_VISIBLE_DEVICES"] = "0"
import torch
from torch.utils.data import DataLoader, Dataset
from torch import nn
from model import build_model
from torch.optim import AdamW
from torch.optim.lr_scheduler import CosineAnnealingLR
from torch.nn.utils import clip_grad_norm_
import numpy as np
import pandas as pd
import os
from tqdm import tqdm 
import matplotlib.pyplot as plt
from torchvision import datasets, transforms

np.random.seed(2023)
torch.manual_seed(2023)
save_dir = "D:/dl/kaggle/2026dian/problem3/result"
device = ('cuda' if torch.cuda.is_available() else 'cpu')
print(device)
# Out:
# cuda

# %%
transform = transforms.Compose([
    transforms.ToTensor(),transforms.Normalize((0.5,),(0.5))
])
train_dataset = datasets.FashionMNIST(
    root = './data',train = True,download = True,
    transform = transform
)
test_dataset = datasets.FashionMNIST(
    root = './data',train = False,download = True,
    transform = transform
)
train_loader = DataLoader(train_dataset,batch_size = 128,shuffle = True)
test_loader = DataLoader(test_dataset,batch_size = 128,shuffle = False)

# 创建保存目录
if not os.path.exists(save_dir):
    os.makedirs(save_dir)
config = {
    'dim':64,
    'patch_size':2,
    'kernel_size':3,
    'img_size':28,
    'num_layers':3,
    'num_classes':10,
    'device':('cuda' if torch.cuda.is_available() else 'cpu')
}

# 构建
model = build_model(config)
criterion = nn.CrossEntropyLoss()
optimizer = AdamW(model.parameters(), lr=0.001,weight_decay=1e-4)
scheduler = CosineAnnealingLR(optimizer, T_max=25)  
num_epochs = 25
train_losses = []
train_accs = []
test_losses = []
test_accs = []
lr_history = []

for epoch in range(num_epochs):
    model.train()
    running_loss = 0.0
    correct = 0
    total = 0
    for images, labels in tqdm(train_loader, desc=f'Epoch {epoch+1}/{num_epochs}'):
        images, labels = images.to(device), labels.to(device)
        optimizer.zero_grad()
        outputs = model(images).to(device)
        loss = criterion(outputs, labels)
        loss.backward()
        optimizer.step()
        
        running_loss += loss.item() * images.size(0)
        _, predicted = torch.max(outputs.data, 1)
        total += labels.size(0)
        correct += (predicted == labels).sum().item()
    
    train_loss = running_loss / len(train_loader.dataset)
    train_acc = 100.0 * correct / total
    print(f'Epoch {epoch+1}/{num_epochs}, Train Loss: {train_loss:.4f}, Train Acc: {train_acc:.2f}%')
    train_losses.append(train_loss)
    train_accs.append(train_acc)
    
    # 测试
    model.eval()
    test_loss = 0.0
    correct = 0
    total = 0
    with torch.no_grad():
        for images, labels in tqdm(test_loader, desc='Testing'):
            images, labels = images.to(device), labels.to(device)
            outputs = model(images)
            loss = criterion(outputs, labels)
            test_loss += loss.item() * images.size(0)
            _, predicted = torch.max(outputs.data, 1)
            total += labels.size(0)
            correct += (predicted == labels).sum().item()
    
    test_loss = test_loss / len(test_loader.dataset)
    test_acc = 100.0 * correct / total
    test_losses.append(test_loss)
    test_accs.append(test_acc)
    
    print(f'Epoch {epoch+1}/{num_epochs}, Train Loss: {train_loss:.4f}, Train Acc: {train_acc:.2f}%, Test Loss: {test_loss:.4f}, Test Acc: {test_acc:.2f}%')
    scheduler.step()
    current_lr = scheduler.get_last_lr()[0]  # 取第一个值
    lr_history.append(current_lr)

# 绘制训练和测试的损失和准确率
plt.figure(figsize=(12, 4))
plt.subplot(1, 3, 1)
plt.plot(range(1, num_epochs+1), train_losses, label='Train Loss')
plt.plot(range(1, num_epochs+1), test_losses, label='Test Loss')
plt.xlabel('Epoch')
plt.ylabel('Loss')
plt.legend()
plt.title('Loss over Epochs')

plt.subplot(1, 3, 2)
plt.plot(range(1, num_epochs+1), train_accs, label='Train Acc')
plt.plot(range(1, num_epochs+1), test_accs, label='Test Acc')
plt.xlabel('Epoch')
plt.ylabel('Accuracy (%)')
plt.legend()
plt.title('Accuracy over Epochs')

plt.subplot(1,3,3)
plt.plot(range(1, num_epochs+1), lr_history, label='Learning Rate')
plt.xlabel('Epoch')
plt.ylabel('Learning Rate')
plt.legend()
plt.title('Learning Rate over Epochs')

plt.tight_layout()
plt.savefig(os.path.join(save_dir, 'acc_and_loss.png'))
plt.show()

# 保存模型
torch.save(model.state_dict(), os.path.join(save_dir, 'model.pth'))
print(f'Model saved to {os.path.join(save_dir, "model.pth")}')
# Out:
# Epoch 1/25: 100%|██████████| 469/469 [03:57<00:00,  1.97it/s]
# Epoch 1/25, Train Loss: 1.4453, Train Acc: 43.64%
# Testing: 100%|██████████| 79/79 [00:09<00:00,  8.61it/s]
# Epoch 1/25, Train Loss: 1.4453, Train Acc: 43.64%, Test Loss: 0.7946, Test Acc: 71.16%
# Epoch 2/25: 100%|██████████| 469/469 [04:00<00:00,  1.95it/s]
# Epoch 2/25, Train Loss: 0.7225, Train Acc: 73.78%
# Testing: 100%|██████████| 79/79 [00:09<00:00,  8.10it/s]
# Epoch 2/25, Train Loss: 0.7225, Train Acc: 73.78%, Test Loss: 0.6343, Test Acc: 77.01%
# Epoch 3/25: 100%|██████████| 469/469 [04:04<00:00,  1.92it/s]
# Epoch 3/25, Train Loss: 0.5966, Train Acc: 78.50%
# Testing: 100%|██████████| 79/79 [00:10<00:00,  7.69it/s]
# Epoch 3/25, Train Loss: 0.5966, Train Acc: 78.50%, Test Loss: 0.6054, Test Acc: 77.51%
# Epoch 4/25: 100%|██████████| 469/469 [04:05<00:00,  1.91it/s]
# Epoch 4/25, Train Loss: 0.5330, Train Acc: 80.88%
# Testing: 100%|██████████| 79/79 [00:10<00:00,  7.29it/s]
# Epoch 4/25, Train Loss: 0.5330, Train Acc: 80.88%, Test Loss: 0.5389, Test Acc: 80.55%
# Epoch 5/25: 100%|██████████| 469/469 [04:08<00:00,  1.89it/s]
# Epoch 5/25, Train Loss: 0.4916, Train Acc: 82.31%
# Testing: 100%|██████████| 79/79 [00:09<00:00,  8.57it/s]
# Epoch 5/25, Train Loss: 0.4916, Train Acc: 82.31%, Test Loss: 0.5266, Test Acc: 81.46%
# Epoch 6/25: 100%|██████████| 469/469 [04:09<00:00,  1.88it/s]
# Epoch 6/25, Train Loss: 0.4652, Train Acc: 83.25%
# Testing: 100%|██████████| 79/79 [00:10<00:00,  7

# Testing: 100%|██████████| 79/79 [00:09<00:00,  8.74it/s]
# Epoch 16/25, Train Loss: 0.3463, Train Acc: 87.42%, Test Loss: 0.3957, Test Acc: 86.56%
# Epoch 17/25: 100%|██████████| 469/469 [03:38<00:00,  2.15it/s]
# Epoch 17/25, Train Loss: 0.3386, Train Acc: 87.59%
# Testing: 100%|██████████| 79/79 [00:09<00:00,  8.74it/s]
# Epoch 17/25, Train Loss: 0.3386, Train Acc: 87.59%, Test Loss: 0.3866, Test Acc: 86.42%
# Epoch 18/25: 100%|██████████| 469/469 [04:36<00:00,  1.70it/s]
# Epoch 18/25, Train Loss: 0.3296, Train Acc: 88.05%
# Testing: 100%|██████████| 79/79 [00:10<00:00,  7.49it/s]
# Epoch 18/25, Train Loss: 0.3296, Train Acc: 88.05%, Test Loss: 0.3717, Test Acc: 86.97%
# Epoch 19/25: 100%|██████████| 469/469 [03:45<00:00,  2.08it/s]
# Epoch 19/25, Train Loss: 0.3233, Train Acc: 88.15%
# Testing: 100%|██████████| 79/79 [00:08<00:00,  8.99it/s]
# Epoch 19/25, Train Loss: 0.3233, Train Acc: 88.15%, Test Loss: 0.3771, Test Acc: 86.90%
# Epoch 20/25: 100%|██████████| 469/469 [03:54<00:00,  2.00it/s]
# Epoch 20/25, Train Loss: 0.3200, Train Acc: 88.38%
# Testing: 100%|██████████| 79/79 [00:10<00:00,  7.89it/s]
# Epoch 20/25, Train Loss: 0.3200, Train Acc: 88.38%, Test Loss: 0.3653, Test Acc: 86.94%
# Epoch 21/25: 100%|██████████| 469/469 [04:10<00:00,  1.87it/s]
# Epoch 21/25, Train Loss: 0.3151, Train Acc: 88.43%
# Testing: 100%|██████████| 79/79 [00:10<00:00,  7.58it/s]
# Epoch 21/25, Train Loss: 0.3151, Train Acc: 88.43%, Test Loss: 0.3687, Test Acc: 87.26%
# Epoch 22/25: 100%|██████████| 469/469 [03:54<00:00,  2.00it/s]
# Epoch 22/25, Train Loss: 0.3119, Train Acc: 88.58%
# Testing: 100%|██████████| 79/79 [00:09<00:00,  8.05it/s]
# Epoch 22/25, Train Loss: 0.3119, Train Acc: 88.58%, Test Loss: 0.3711, Test Acc: 87.07%
# Epoch 23/25: 100%|██████████| 469/469 [04:13<00:00,  1.85it/s]
# Epoch 23/25, Train Loss: 0.3092, Train Acc: 88.79%
# Testing: 100%|██████████| 79/79 [00:09<00:00,  8.32it/s]
# Epoch 23/25, Train Loss: 0.3092, Train Acc: 88.79%, Test Loss: 0.3679, Test Acc: 87.24%
# Epoch 24/25: 100%|██████████| 469/469 [03:42<00:00,  2.11it/s]
# Epoch 24/25, Train Loss: 0.3067, Train Acc: 88.87%
# Testing: 100%|██████████| 79/79 [00:07<00:00,  9.96it/s]
# Epoch 24/25, Train Loss: 0.3067, Train Acc: 88.87%, Test Loss: 0.3631, Test Acc: 87.27%
# Epoch 25/25: 100%|██████████| 469/469 [03:36<00:00,  2.17it/s]
# Epoch 25/25, Train Loss: 0.3066, Train Acc: 88.72%
# Testing: 100%|██████████| 79/79 [00:10<00:00,  7.61it/s]
# Epoch 25/25, Train Loss: 0.3066, Train Acc: 88.72%, Test Loss: 0.3652, Test Acc: 87.15%
# Model saved to D:/dl/kaggle/2026dian/problem3/result\model.pth
